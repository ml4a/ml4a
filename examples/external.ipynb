# %%
import neuralarttools.external.basnet as basnet
from neuralarttools.image import *

img = load_image('https://upload.wikimedia.org/wikipedia/commons/6/6a/Mona_Lisa.jpg', (220, 350))
img_fg = basnet.get_foreground(img)
display(img_fg)
# Out:
# <PIL.Image.Image image mode=RGB size=220x350 at 0x7F165BDED0B8>
