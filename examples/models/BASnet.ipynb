# %% [markdown]
# # BASNet: Salient Object Detection
# ## [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ml4a/ml4a-guides/blob/ml4a.net/examples/models/BASnet.ipynb)
#
# <a href="https://colab.research.google.com/github/ml4a/ml4a-guides/blob/ml4a.net/examples/models/BASnet.ipynb" target="_blank"><img src="https://colab.research.google.com/assets/colab-badge.svg" /></a>
#
# Outputs mask of an image's salient objects (foreground). [original code](https://github.com/NathanUA/BASNet) & [paper](https://openaccess.thecvf.com/content_CVPR_2019/html/Qin_BASNet_Boundary-Aware_Salient_Object_Detection_CVPR_2019_paper.html).

# %% [markdown]
# ## Set up ml4a
#
# If you don't already have ml4a and dependencies installed, or you are opening this in Colab, you may install ml4a by running the following cell.

# %%
# %tensorflow_version 1.x
# !pip3 install --quiet git+https://github.com/ml4a/ml4a-guides.git@ml4a.net#egg=ml4a

# %% [markdown]
# ## Run BASNet

# %%
from ml4a.models import basnet
from ml4a import image, mask

img = image.load_image('https://upload.wikimedia.org/wikipedia/commons/6/6a/Mona_Lisa.jpg', (220, 350))
img_fg = basnet.get_foreground(img)
img_masked = mask.mask_image(img_fg, img)

all_images = image.concatenate_images([img, img_fg, img_masked])
image.display(all_images)
# Out:
# <PIL.Image.Image image mode=RGB size=660x350 at 0x7F0D301D2470>
