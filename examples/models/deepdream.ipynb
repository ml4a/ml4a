# %%
# %load_ext autoreload
# %autoreload 2

from ml4a import image
from ml4a.models import deepdream
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
deepdream.test()
# Out:
# <PIL.Image.Image image mode=RGB size=336x512 at 0x7F81FC17C0B8>
