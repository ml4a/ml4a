# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np

from ml4a import image
from ml4a.models import cartoonization

img = image.load_image('https://upload.wikimedia.org/wikipedia/commons/thumb/8/8d/Vladimir_Putin_%282020-02-20%29.jpg/1200px-Vladimir_Putin_%282020-02-20%29.jpg')
img = image.resize(img, (560, 720))

img2 = cartoonization.run(img)

# todo: fix array bug
image.display([np.array(img), img2])
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# MUST SETUP
# WARNING:tensorflow:From /home/bzion/projects/ml4a/ml4a-guides/ml4a/models/cartoonization.py:41: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/bzion/projects/ml4a/ml4a-guides/ml4a/models/submodules/White-box-Cartoonization/test_code/network.py:23: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# ...

# %%
import numpy as np
imgg = np.array([img, img2])
h, w = np.array(imgg[0]).shape[:2]
h, w
# Out:
# (720, 560)

# %%
import numpy as np
np.array(img).shape, np.array(img2).shape
# Out:
# ((720, 560, 3), (720, 560, 3))

# %%
(np.repeat(np.array(img), 1)).shape
# Out:
# (1209600,)

# %%
img = np.repeat(np.array(img)[np.newaxis, :, :], 8, axis=0)
print(np.array(img).shape, b.shape)
# Out:
# (720, 560, 3) (8, 720, 560, 3)
