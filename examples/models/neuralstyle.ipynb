# %%
# %load_ext autoreload
# %autoreload 2

from ml4a import image
from ml4a.models import neuralstyle

# %%
neuralstyle.test()
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F2CAF2B4518>
