# %%
# %load_ext autoreload
# %autoreload 2

from ml4a import image
from ml4a.models import neuralstyle

# %%
stylenet = neuralstyle.setup()
# Out:
# Model setup successfully with parameters:
# gpu: 0, optimizer: lbfgs, learning_rate: 1.00, lbfgs_num_correction: 100, pooling: max, model_file: /home/bzion/.ml4a/models/neural_style/vgg19-d01eb7cb.pth, False, backend: cudnn, False, content_layers: relu4_2, style_layers: relu1_1,relu2_1,relu3_1,relu4_1,relu5_1, hist_layers: relu2_1,relu3_1,relu4_1,relu5_1, multidevice_strategy: 4,7,29

# %%
config = {
    'content_image': 'https://pbs.twimg.com/profile_images/881165835733258240/MqEwr8AE.jpg',
    'style_image': 'https://www.phocuswire.com/uploadedImages/Articles/Opinion/2020/July/travel-bubbles-covid-19.jpeg'
}

img = neuralstyle.style_transfer(stylenet, config)
image.display(img)
# Out:
# Iteration 400/1000:
#   Content loss = 3.1e+06
#   Style loss = 1.8e+03, 8.9e+03, 1.3e+04, 2.3e+05, 6.6e+03
#   Histogram loss =
#   TV loss = 2.9e+04
#   Total loss = 3.36e+06
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FDA9C9C8630>
