# %% [markdown]
# # Real-ESRGAN: Image super-resolution and enhancement
#
# ## [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ml4a/ml4a-guides/blob/ml4a.net/examples/models/Real_ESRGAN.ipynb)
#
# Upscales an image's pixel resolution by 4x. See the [original code](https://github.com/xinntao/Real-ESRGAN/) and [paper](https://arxiv.org/abs/2107.10833).

# %% [markdown]
# ## Set up ml4a and enable GPU
#
# If you don't already have ml4a installed, or you are opening this in Colab, first enable GPU (`Runtime` > `Change runtime type`), then run the following cell to install ml4a and its dependencies.

# %%
# %tensorflow_version 1.x
# !pip3 install --quiet ml4a

# %% [markdown]
# ## Upsample an image
#
# We start with a small image and upsample it 4x using Real-ESRGAN.

# %%
from ml4a import image
from ml4a.models import real_esrgan

# load image from the web
img1 = image.load_image('https://raw.githubusercontent.com/xinntao/ESRGAN/master/LR/baboon.png')

# or you can load an image directly from disk
#img1 = image.load_image('my_file.jpg')

# run Real-ESRGAN
img2 = real_esrgan.run(img1)

# display
image.display(img1, title="original image")
image.display(img2, title="upsampled 4x")
# Out:
# original image
# <PIL.Image.Image image mode=RGB size=125x120 at 0x7F1700C35F28>
# upsampled 4x
# <PIL.Image.Image image mode=RGB size=500x480 at 0x7F18444662E8>
